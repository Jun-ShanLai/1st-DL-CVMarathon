# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = '../data/training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0206 13:13:34.367942  6224 __init__.py:308] Limited tf.compat.v2.summary API due to missing TensorBoard installation.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# W0206 13:13:34.533652  6224 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\Tesseract\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0206 13:13:34.545028  6224 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\Tesseract\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0206 13:13:34.547024  6224 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\Tesseract\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0206 13:13:34.556029  6224 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\Tesseract\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0206 13:13:34.593926  6224 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\Tesseract\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0206 13:13:34.598913  6224 deprecation.py:506] From C:\Users\user\Anaconda3\envs\Tesseract\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0206 13:13:34.633828  6224 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\Tesseract\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# W0206 13:13:34.782890  6224 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\Tesseract\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 0.0089 - val_loss: 0.0027
#
# Epoch 00001: val_loss improved from inf to 0.00269, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 1s 446us/step - loss: 0.0022 - val_loss: 0.0020
#
# Epoch 00002: val_loss improved from 0.00269 to 0.00196, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 1s 451us/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00196 to 0.00188, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 1s 452us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00188
# Epoch 5/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00188
# Epoch 6/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00188 to 0.00182, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 1s 444us/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00007: val_loss improved from 0.00182 to 0.00182, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 9.7113e-04 - val_loss: 0.0017
#
# Epoch 00008: val_loss improved from 0.00182 to 0.00172, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 8.3115e-04 - val_loss: 0.0016
#
# Epoch 00009: val_loss improved from 0.00172 to 0.00164, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 7.1717e-04 - val_loss: 0.0015
#
# Epoch 00010: val_loss improved from 0.00164 to 0.00151, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 1s 452us/step - loss: 6.6334e-04 - val_loss: 0.0014
#
# Epoch 00011: val_loss improved from 0.00151 to 0.00136, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 1s 449us/step - loss: 6.0475e-04 - val_loss: 0.0013
#
# Epoch 00012: val_loss improved from 0.00136 to 0.00129, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 1s 453us/step - loss: 5.6054e-04 - val_loss: 0.0012
#
# Epoch 00013: val_loss improved from 0.00129 to 0.00121, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 5.3268e-04 - val_loss: 0.0011
#
# Epoch 00014: val_loss improved from 0.00121 to 0.00111, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 1s 446us/step - loss: 4.8858e-04 - val_loss: 0.0011
#
# Epoch 00015: val_loss improved from 0.00111 to 0.00110, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 1s 453us/step - loss: 4.5938e-04 - val_loss: 0.0011
#
# Epoch 00016: val_loss improved from 0.00110 to 0.00107, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 1s 446us/step - loss: 4.3829e-04 - val_loss: 0.0010
#
# Epoch 00017: val_loss improved from 0.00107 to 0.00101, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 1s 444us/step - loss: 4.0582e-04 - val_loss: 9.8956e-04
#
# Epoch 00018: val_loss improved from 0.00101 to 0.00099, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 3.9606e-04 - val_loss: 9.6626e-04
#
# Epoch 00019: val_loss improved from 0.00099 to 0.00097, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 3.6755e-04 - val_loss: 9.0411e-04
#
# Epoch 00020: val_loss improved from 0.00097 to 0.00090, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 1s 453us/step - loss: 3.6004e-04 - val_loss: 9.2350e-04
#
# Epoch 00021: val_loss did not improve from 0.00090
# Epoch 22/150
# 1712/1712 [==============================] - 1s 453us/step - loss: 3.5628e-04 - val_loss: 9.3894e-04
#
# Epoch 00022: val_loss did not improve from 0.00090
# Epoch 23/150
# 1712/1712 [==============================] - 1s 453us/step - loss: 3.3657e-04 - val_loss: 8.6786e-04
#
# Epoch 00023: val_loss improved from 0.00090 to 0.00087, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 1s 453us/step - loss: 3.2945e-04 - val_loss: 8.9044e-04
#
# Epoch 00024: val_loss did not improve from 0.00087
# Epoch 25/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 3.1236e-04 - val_loss: 8.9638e-04
#
# Epoch 00025: val_loss did not improve from 0.00087
# Epoch 26/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 3.0753e-04 - val_loss: 8.6722e-04
#
# Epoch 00026: val_loss improved from 0.00087 to 0.00087, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 2.9860e-04 - val_loss: 8.6581e-04
#
# Epoch 00027: val_loss improved from 0.00087 to 0.00087, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 2.9143e-04 - val_loss: 8.5537e-04
#
# Epoch 00028: val_loss improved from 0.00087 to 0.00086, saving model to best_weights.h5
# Epoch 29/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 2.8258e-04 - val_loss: 8.5032e-04
#
# Epoch 00029: val_loss improved from 0.00086 to 0.00085, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 1s 451us/step - loss: 2.6810e-04 - val_loss: 8.2243e-04
#
# Epoch 00030: val_loss improved from 0.00085 to 0.00082, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 1s 452us/step - loss: 2.7111e-04 - val_loss: 8.3554e-04
#
# Epoch 00031: val_loss did not improve from 0.00082
# Epoch 32/150
# 1712/1712 [==============================] - 1s 451us/step - loss: 2.6338e-04 - val_loss: 8.1557e-04
#
# Epoch 00032: val_loss improved from 0.00082 to 0.00082, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 1s 445us/step - loss: 2.5671e-04 - val_loss: 8.2038e-04
#
# Epoch 00033: val_loss did not improve from 0.00082
# Epoch 34/150
# 1712/1712 [==============================] - 1s 463us/step - loss: 2.5354e-04 - val_loss: 8.0249e-04
#
# Epoch 00034: val_loss improved from 0.00082 to 0.00080, saving model to best_weights.h5
# Epoch 35/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 2.5022e-04 - val_loss: 8.4665e-04
#
# Epoch 00035: val_loss did not improve from 0.00080
# Epoch 36/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 2.4576e-04 - val_loss: 8.2080e-04
#
# Epoch 00036: val_loss did not improve from 0.00080
# Epoch 37/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 2.4442e-04 - val_loss: 7.7686e-04
#
# Epoch 00037: val_loss improved from 0.00080 to 0.00078, saving model to best_weights.h5
# Epoch 38/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 2.4380e-04 - val_loss: 8.1838e-04
#
# Epoch 00038: val_loss did not improve from 0.00078
# Epoch 39/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 2.2942e-04 - val_loss: 8.5858e-04
#
# Epoch 00039: val_loss did not improve from 0.00078
# Epoch 40/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 2.3469e-04 - val_loss: 8.1657e-04
#
# Epoch 00040: val_loss did not improve from 0.00078
# Epoch 41/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 2.2312e-04 - val_loss: 8.0465e-04
#
# Epoch 00041: val_loss did not improve from 0.00078
# Epoch 42/150
# 1712/1712 [==============================] - 1s 449us/step - loss: 2.1945e-04 - val_loss: 7.8864e-04
#
# Epoch 00042: val_loss did not improve from 0.00078
# Epoch 43/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 2.1760e-04 - val_loss: 7.9708e-04
#
# Epoch 00043: val_loss did not improve from 0.00078
# Epoch 44/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 2.1192e-04 - val_loss: 8.3580e-04
#
# Epoch 00044: val_loss did not improve from 0.00078
# Epoch 45/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 2.1635e-04 - val_loss: 8.0621e-04
#
# Epoch 00045: val_loss did not improve from 0.00078
# Epoch 46/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 2.0787e-04 - val_loss: 7.8124e-04
#
# Epoch 00046: val_loss did not improve from 0.00078
# Epoch 47/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 2.0150e-04 - val_loss: 7.9256e-04
#
# Epoch 00047: val_loss did not improve from 0.00078
# Epoch 48/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 2.0143e-04 - val_loss: 7.7119e-04
#
# Epoch 00048: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 49/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 2.0376e-04 - val_loss: 8.2361e-04
#
# Epoch 00049: val_loss did not improve from 0.00077
# Epoch 50/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 2.0438e-04 - val_loss: 8.0237e-04
#
# Epoch 00050: val_loss did not improve from 0.00077
# Epoch 51/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.9021e-04 - val_loss: 7.8269e-04
#
# Epoch 00051: val_loss did not improve from 0.00077
# Epoch 52/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.8987e-04 - val_loss: 7.6976e-04
#
# Epoch 00052: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 53/150
# 1712/1712 [==============================] - 1s 452us/step - loss: 1.9056e-04 - val_loss: 7.8981e-04
#
# Epoch 00053: val_loss did not improve from 0.00077
# Epoch 54/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.9372e-04 - val_loss: 8.0768e-04
#
# Epoch 00054: val_loss did not improve from 0.00077
# Epoch 55/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.8322e-04 - val_loss: 7.8417e-04
#
# Epoch 00055: val_loss did not improve from 0.00077
# Epoch 56/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.8096e-04 - val_loss: 7.7784e-04
#
# Epoch 00056: val_loss did not improve from 0.00077
# Epoch 57/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.9086e-04 - val_loss: 7.9362e-04
#
# Epoch 00057: val_loss did not improve from 0.00077
# Epoch 58/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.8091e-04 - val_loss: 7.8966e-04
#
# Epoch 00058: val_loss did not improve from 0.00077
# Epoch 59/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.7308e-04 - val_loss: 7.5386e-04
#
# Epoch 00059: val_loss improved from 0.00077 to 0.00075, saving model to best_weights.h5
# Epoch 60/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 1.7091e-04 - val_loss: 7.4991e-04
#
# Epoch 00060: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 61/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.6938e-04 - val_loss: 7.8537e-04
#
# Epoch 00061: val_loss did not improve from 0.00075
# Epoch 62/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 1.7381e-04 - val_loss: 7.8725e-04
#
# Epoch 00062: val_loss did not improve from 0.00075
# Epoch 63/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.6863e-04 - val_loss: 7.5011e-04
#
# Epoch 00063: val_loss did not improve from 0.00075
# Epoch 64/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.6657e-04 - val_loss: 7.7402e-04
#
# Epoch 00064: val_loss did not improve from 0.00075
# Epoch 65/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.6944e-04 - val_loss: 7.7658e-04
#
# Epoch 00065: val_loss did not improve from 0.00075
# Epoch 66/150
# 1712/1712 [==============================] - 1s 453us/step - loss: 1.6530e-04 - val_loss: 7.7978e-04
#
# Epoch 00066: val_loss did not improve from 0.00075
# Epoch 67/150
# 1712/1712 [==============================] - 1s 453us/step - loss: 1.6521e-04 - val_loss: 7.7079e-04
#
# Epoch 00067: val_loss did not improve from 0.00075
# Epoch 68/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 1.6322e-04 - val_loss: 8.1499e-04
#
# Epoch 00068: val_loss did not improve from 0.00075
# Epoch 69/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.5872e-04 - val_loss: 8.1124e-04
#
# Epoch 00069: val_loss did not improve from 0.00075
# Epoch 70/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.6414e-04 - val_loss: 7.8061e-04
#
# Epoch 00070: val_loss did not improve from 0.00075
# Epoch 71/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.5528e-04 - val_loss: 7.4954e-04
#
# Epoch 00071: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 72/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.5517e-04 - val_loss: 7.8788e-04
#
# Epoch 00072: val_loss did not improve from 0.00075
# Epoch 73/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 1.6015e-04 - val_loss: 7.5569e-04
#
# Epoch 00073: val_loss did not improve from 0.00075
# Epoch 74/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.5430e-04 - val_loss: 7.4465e-04
#
# Epoch 00074: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 75/150
# 1712/1712 [==============================] - 1s 453us/step - loss: 1.5240e-04 - val_loss: 7.4829e-04
#
# Epoch 00075: val_loss did not improve from 0.00074
# Epoch 76/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.5138e-04 - val_loss: 7.5579e-04
#
# Epoch 00076: val_loss did not improve from 0.00074
# Epoch 77/150
# 1712/1712 [==============================] - 1s 449us/step - loss: 1.4782e-04 - val_loss: 7.4668e-04
#
# Epoch 00077: val_loss did not improve from 0.00074
# Epoch 78/150
# 1712/1712 [==============================] - 1s 461us/step - loss: 1.4740e-04 - val_loss: 7.4776e-04
#
# Epoch 00078: val_loss did not improve from 0.00074
# Epoch 79/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.4772e-04 - val_loss: 7.3540e-04
#
# Epoch 00079: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 80/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.4474e-04 - val_loss: 7.6587e-04
#
# Epoch 00080: val_loss did not improve from 0.00074
# Epoch 81/150
# 1712/1712 [==============================] - 1s 449us/step - loss: 1.3911e-04 - val_loss: 7.7394e-04
#
# Epoch 00081: val_loss did not improve from 0.00074
# Epoch 82/150
# 1712/1712 [==============================] - 1s 463us/step - loss: 1.3976e-04 - val_loss: 8.1042e-04
#
# Epoch 00082: val_loss did not improve from 0.00074
# Epoch 83/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.3916e-04 - val_loss: 7.7913e-04
#
# Epoch 00083: val_loss did not improve from 0.00074
# Epoch 84/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.3914e-04 - val_loss: 7.7606e-04
#
# Epoch 00084: val_loss did not improve from 0.00074
# Epoch 85/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.3557e-04 - val_loss: 7.8859e-04
#
# Epoch 00085: val_loss did not improve from 0.00074
# Epoch 86/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 1.3802e-04 - val_loss: 7.8803e-04
#
# Epoch 00086: val_loss did not improve from 0.00074
# Epoch 87/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.3829e-04 - val_loss: 7.4735e-04
#
# Epoch 00087: val_loss did not improve from 0.00074
# Epoch 88/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.3578e-04 - val_loss: 7.6085e-04
#
# Epoch 00088: val_loss did not improve from 0.00074
# Epoch 89/150
# 1712/1712 [==============================] - 1s 450us/step - loss: 1.3623e-04 - val_loss: 7.7061e-04
#
# Epoch 00089: val_loss did not improve from 0.00074
# Epoch 90/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.3516e-04 - val_loss: 7.6972e-04
#
# Epoch 00090: val_loss did not improve from 0.00074
# Epoch 91/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.3714e-04 - val_loss: 7.5646e-04
#
# Epoch 00091: val_loss did not improve from 0.00074
# Epoch 92/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.3103e-04 - val_loss: 7.3854e-04
#
# Epoch 00092: val_loss did not improve from 0.00074
# Epoch 93/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 1.3238e-04 - val_loss: 7.4852e-04
#
# Epoch 00093: val_loss did not improve from 0.00074
# Epoch 94/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.2675e-04 - val_loss: 7.7797e-04
#
# Epoch 00094: val_loss did not improve from 0.00074
# Epoch 95/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 1.2710e-04 - val_loss: 7.6114e-04
#
# Epoch 00095: val_loss did not improve from 0.00074
# Epoch 96/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.2789e-04 - val_loss: 7.7771e-04
#
# Epoch 00096: val_loss did not improve from 0.00074
# Epoch 97/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 1.2802e-04 - val_loss: 7.5925e-04
#
# Epoch 00097: val_loss did not improve from 0.00074
# Epoch 98/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.2855e-04 - val_loss: 7.8720e-04
#
# Epoch 00098: val_loss did not improve from 0.00074
# Epoch 99/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.2324e-04 - val_loss: 7.5510e-04
#
# Epoch 00099: val_loss did not improve from 0.00074
# Epoch 100/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.2092e-04 - val_loss: 7.5687e-04
#
# Epoch 00100: val_loss did not improve from 0.00074
# Epoch 101/150
# 1712/1712 [==============================] - 1s 448us/step - loss: 1.1747e-04 - val_loss: 7.4755e-04
#
# Epoch 00101: val_loss did not improve from 0.00074
# Epoch 102/150
# 1712/1712 [==============================] - 1s 461us/step - loss: 1.2054e-04 - val_loss: 7.5076e-04
#
# Epoch 00102: val_loss did not improve from 0.00074
# Epoch 103/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 1.2018e-04 - val_loss: 7.9602e-04
#
# Epoch 00103: val_loss did not improve from 0.00074
# Epoch 104/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.2083e-04 - val_loss: 8.0971e-04
#
# Epoch 00104: val_loss did not improve from 0.00074
# Epoch 105/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.2566e-04 - val_loss: 7.9503e-04
#
# Epoch 00105: val_loss did not improve from 0.00074
# Epoch 106/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.2172e-04 - val_loss: 7.4714e-04
#
# Epoch 00106: val_loss did not improve from 0.00074
# Epoch 107/150
# 1712/1712 [==============================] - 1s 453us/step - loss: 1.1757e-04 - val_loss: 7.5867e-04
#
# Epoch 00107: val_loss did not improve from 0.00074
# Epoch 108/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.1535e-04 - val_loss: 7.5813e-04
#
# Epoch 00108: val_loss did not improve from 0.00074
# Epoch 109/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.1440e-04 - val_loss: 7.8057e-04
#
# Epoch 00109: val_loss did not improve from 0.00074
# Epoch 110/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.1358e-04 - val_loss: 7.8428e-04
#
# Epoch 00110: val_loss did not improve from 0.00074
# Epoch 111/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.1162e-04 - val_loss: 7.5462e-04
#
# Epoch 00111: val_loss did not improve from 0.00074
# Epoch 112/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.1105e-04 - val_loss: 7.4287e-04
#
# Epoch 00112: val_loss did not improve from 0.00074
# Epoch 113/150
# 1712/1712 [==============================] - 1s 453us/step - loss: 1.1317e-04 - val_loss: 7.8067e-04
#
# Epoch 00113: val_loss did not improve from 0.00074
# Epoch 114/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.1557e-04 - val_loss: 7.7706e-04
#
# Epoch 00114: val_loss did not improve from 0.00074
# Epoch 115/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.1624e-04 - val_loss: 8.0616e-04
#
# Epoch 00115: val_loss did not improve from 0.00074
# Epoch 116/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.0951e-04 - val_loss: 7.8768e-04
#
# Epoch 00116: val_loss did not improve from 0.00074
# Epoch 117/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.0825e-04 - val_loss: 7.6570e-04
#
# Epoch 00117: val_loss did not improve from 0.00074
# Epoch 118/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.1420e-04 - val_loss: 7.6085e-04
#
# Epoch 00118: val_loss did not improve from 0.00074
# Epoch 119/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.0817e-04 - val_loss: 7.9012e-04
#
# Epoch 00119: val_loss did not improve from 0.00074
# Epoch 120/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.0648e-04 - val_loss: 7.8558e-04
#
# Epoch 00120: val_loss did not improve from 0.00074
# Epoch 121/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.0656e-04 - val_loss: 7.8537e-04
#
# Epoch 00121: val_loss did not improve from 0.00074
# Epoch 122/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.0720e-04 - val_loss: 7.5347e-04
#
# Epoch 00122: val_loss did not improve from 0.00074
# Epoch 123/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.0550e-04 - val_loss: 7.4990e-04
#
# Epoch 00123: val_loss did not improve from 0.00074
# Epoch 124/150
# 1712/1712 [==============================] - 1s 450us/step - loss: 1.0870e-04 - val_loss: 7.9145e-04
#
# Epoch 00124: val_loss did not improve from 0.00074
# Epoch 125/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.0650e-04 - val_loss: 7.8930e-04
#
# Epoch 00125: val_loss did not improve from 0.00074
# Epoch 126/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.0339e-04 - val_loss: 7.6734e-04
#
# Epoch 00126: val_loss did not improve from 0.00074
# Epoch 127/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.0291e-04 - val_loss: 7.8567e-04
#
# Epoch 00127: val_loss did not improve from 0.00074
# Epoch 128/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.0490e-04 - val_loss: 7.8295e-04
#
# Epoch 00128: val_loss did not improve from 0.00074
# Epoch 129/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.0092e-04 - val_loss: 7.7165e-04
#
# Epoch 00129: val_loss did not improve from 0.00074
# Epoch 130/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 9.8444e-05 - val_loss: 8.0406e-04
#
# Epoch 00130: val_loss did not improve from 0.00074
# Epoch 131/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.0104e-04 - val_loss: 7.7040e-04
#
# Epoch 00131: val_loss did not improve from 0.00074
# Epoch 132/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.0036e-04 - val_loss: 7.6543e-04
#
# Epoch 00132: val_loss did not improve from 0.00074
# Epoch 133/150
# 1712/1712 [==============================] - 1s 449us/step - loss: 1.0247e-04 - val_loss: 7.9052e-04
#
# Epoch 00133: val_loss did not improve from 0.00074
# Epoch 134/150
# 1712/1712 [==============================] - 1s 462us/step - loss: 9.6682e-05 - val_loss: 7.5381e-04
#
# Epoch 00134: val_loss did not improve from 0.00074
# Epoch 135/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 9.7537e-05 - val_loss: 7.5495e-04
#
# Epoch 00135: val_loss did not improve from 0.00074
# Epoch 136/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 9.8323e-05 - val_loss: 7.7492e-04
#
# Epoch 00136: val_loss did not improve from 0.00074
# Epoch 137/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 9.6722e-05 - val_loss: 7.5894e-04
#
# Epoch 00137: val_loss did not improve from 0.00074
# Epoch 138/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 9.8176e-05 - val_loss: 7.6721e-04
#
# Epoch 00138: val_loss did not improve from 0.00074
# Epoch 139/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 9.8214e-05 - val_loss: 7.4630e-04
#
# Epoch 00139: val_loss did not improve from 0.00074
# Epoch 140/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 9.7149e-05 - val_loss: 7.5163e-04
#
# Epoch 00140: val_loss did not improve from 0.00074
# Epoch 141/150
# 1712/1712 [==============================] - 1s 450us/step - loss: 9.9627e-05 - val_loss: 7.7387e-04
#
# Epoch 00141: val_loss did not improve from 0.00074
# Epoch 142/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 9.8011e-05 - val_loss: 7.6469e-04
#
# Epoch 00142: val_loss did not improve from 0.00074
# Epoch 143/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 9.3894e-05 - val_loss: 7.7166e-04
#
# Epoch 00143: val_loss did not improve from 0.00074
# Epoch 144/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 9.2794e-05 - val_loss: 7.9210e-04
#
# Epoch 00144: val_loss did not improve from 0.00074
# Epoch 145/150
# 1712/1712 [==============================] - 1s 451us/step - loss: 9.1674e-05 - val_loss: 8.0383e-04
#
# Epoch 00145: val_loss did not improve from 0.00074
# Epoch 146/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 9.2681e-05 - val_loss: 7.9507e-04
#
# Epoch 00146: val_loss did not improve from 0.00074
# Epoch 147/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 9.2368e-05 - val_loss: 7.9561e-04
#
# Epoch 00147: val_loss did not improve from 0.00074
# Epoch 148/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 9.1440e-05 - val_loss: 7.9192e-04
#
# Epoch 00148: val_loss did not improve from 0.00074
# Epoch 149/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 9.0496e-05 - val_loss: 7.9964e-04
#
# Epoch 00149: val_loss did not improve from 0.00074
# Epoch 150/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 9.2603e-05 - val_loss: 7.8551e-04
#
# Epoch 00150: val_loss did not improve from 0.00074

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = '../data/test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %% [markdown]
# ### 作業
#
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rotation_range=40,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   channel_shift_range=10,
                                   horizontal_flip=True,
                                   fill_mode='nearest',
                                   validation_split=0.2)

train_X = imgs_train.reshape(-1, 96, 96, 1)
training_set = train_datagen.flow(train_X, points_train,batch_size = 32)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
'''
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
'''


hist_model_aug = model_with_augment.fit_generator(training_set, steps_per_epoch = len(train_X) // 32, nb_epoch = 20, callbacks=[checkpoint, hist], shuffle=True, validation_data=(train_X, points_train))
# Out:
# C:\Users\user\Anaconda3\envs\Tesseract\lib\site-packages\ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# C:\Users\user\Anaconda3\envs\Tesseract\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., steps_per_epoch=66, callbacks=[<keras.ca..., shuffle=True, validation_data=(array([[[..., epochs=20)`
#   if sys.path[0] == '':
# Epoch 1/20
# 66/66 [==============================] - 2s 30ms/step - loss: 0.0041 - val_loss: 0.0011
#
# Epoch 00001: val_loss did not improve from 0.00074
# Epoch 2/20
# 66/66 [==============================] - 1s 23ms/step - loss: 0.0014 - val_loss: 0.0011
#
# Epoch 00002: val_loss did not improve from 0.00074
# Epoch 3/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00003: val_loss did not improve from 0.00074
# Epoch 4/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00004: val_loss did not improve from 0.00074
# Epoch 5/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00005: val_loss did not improve from 0.00074
# Epoch 6/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00006: val_loss did not improve from 0.00074
# Epoch 7/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00007: val_loss did not improve from 0.00074
# Epoch 8/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00008: val_loss did not improve from 0.00074
# Epoch 9/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00009: val_loss did not improve from 0.00074
# Epoch 10/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00010: val_loss did not improve from 0.00074
# Epoch 11/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00011: val_loss did not improve from 0.00074
# Epoch 12/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00012: val_loss did not improve from 0.00074
# Epoch 13/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00013: val_loss did not improve from 0.00074
# Epoch 14/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00014: val_loss did not improve from 0.00074
# Epoch 15/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00015: val_loss did not improve from 0.00074
# Epoch 16/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00016: val_loss did not improve from 0.00074
# Epoch 17/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00017: val_loss did not improve from 0.00074
# Epoch 18/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00018: val_loss did not improve from 0.00074
# Epoch 19/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00019: val_loss did not improve from 0.00074
# Epoch 20/20
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00020: val_loss did not improve from 0.00074

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# ### 官方解答

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 2s 639us/step - loss: 0.0037 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00205, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00002: val_loss improved from 0.00205 to 0.00177, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 0.0011 - val_loss: 0.0017
#
# Epoch 00003: val_loss improved from 0.00177 to 0.00169, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 2s 454us/step - loss: 7.6523e-04 - val_loss: 0.0013
#
# Epoch 00004: val_loss improved from 0.00169 to 0.00126, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 5.9842e-04 - val_loss: 0.0011
#
# Epoch 00005: val_loss improved from 0.00126 to 0.00112, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 5.0000e-04 - val_loss: 9.8177e-04
#
# Epoch 00006: val_loss improved from 0.00112 to 0.00098, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 4.4528e-04 - val_loss: 8.9285e-04
#
# Epoch 00007: val_loss improved from 0.00098 to 0.00089, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 4.1065e-04 - val_loss: 8.8560e-04
#
# Epoch 00008: val_loss improved from 0.00089 to 0.00089, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 3.7618e-04 - val_loss: 8.2159e-04
#
# Epoch 00009: val_loss improved from 0.00089 to 0.00082, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 3.5765e-04 - val_loss: 7.7492e-04
#
# Epoch 00010: val_loss improved from 0.00082 to 0.00077, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 3.2855e-04 - val_loss: 7.6055e-04
#
# Epoch 00011: val_loss improved from 0.00077 to 0.00076, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 3.1203e-04 - val_loss: 7.3594e-04
#
# Epoch 00012: val_loss improved from 0.00076 to 0.00074, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 2.9447e-04 - val_loss: 7.3334e-04
#
# Epoch 00013: val_loss improved from 0.00074 to 0.00073, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 2.8019e-04 - val_loss: 6.8581e-04
#
# Epoch 00014: val_loss improved from 0.00073 to 0.00069, saving model to best_weights_augment.h5
# Epoch 15/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 2.7547e-04 - val_loss: 6.9609e-04
#
# Epoch 00015: val_loss did not improve from 0.00069
# Epoch 16/150
# 3424/3424 [==============================] - 2s 458us/step - loss: 2.6651e-04 - val_loss: 7.1321e-04
#
# Epoch 00016: val_loss did not improve from 0.00069
# Epoch 17/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 2.5272e-04 - val_loss: 6.6658e-04
#
# Epoch 00017: val_loss improved from 0.00069 to 0.00067, saving model to best_weights_augment.h5
# Epoch 18/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 2.4661e-04 - val_loss: 6.7598e-04
#
# Epoch 00018: val_loss did not improve from 0.00067
# Epoch 19/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 2.4375e-04 - val_loss: 6.7210e-04
#
# Epoch 00019: val_loss did not improve from 0.00067
# Epoch 20/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 2.3424e-04 - val_loss: 6.7006e-04
#
# Epoch 00020: val_loss did not improve from 0.00067
# Epoch 21/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 2.2289e-04 - val_loss: 6.9231e-04
#
# Epoch 00021: val_loss did not improve from 0.00067
# Epoch 22/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 2.2091e-04 - val_loss: 6.6858e-04
#
# Epoch 00022: val_loss did not improve from 0.00067
# Epoch 23/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 2.1322e-04 - val_loss: 6.5171e-04
#
# Epoch 00023: val_loss improved from 0.00067 to 0.00065, saving model to best_weights_augment.h5
# Epoch 24/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 2.1234e-04 - val_loss: 7.0124e-04
#
# Epoch 00024: val_loss did not improve from 0.00065
# Epoch 25/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 2.0262e-04 - val_loss: 6.4947e-04
#
# Epoch 00025: val_loss improved from 0.00065 to 0.00065, saving model to best_weights_augment.h5
# Epoch 26/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 2.0089e-04 - val_loss: 6.3464e-04
#
# Epoch 00026: val_loss improved from 0.00065 to 0.00063, saving model to best_weights_augment.h5
# Epoch 27/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.9239e-04 - val_loss: 6.3989e-04
#
# Epoch 00027: val_loss did not improve from 0.00063
# Epoch 28/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.9549e-04 - val_loss: 6.2400e-04
#
# Epoch 00028: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 29/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 1.8983e-04 - val_loss: 6.7579e-04
#
# Epoch 00029: val_loss did not improve from 0.00062
# Epoch 30/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.8517e-04 - val_loss: 6.5050e-04
#
# Epoch 00030: val_loss did not improve from 0.00062
# Epoch 31/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.7908e-04 - val_loss: 6.4227e-04
#
# Epoch 00031: val_loss did not improve from 0.00062
# Epoch 32/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.8503e-04 - val_loss: 6.0734e-04
#
# Epoch 00032: val_loss improved from 0.00062 to 0.00061, saving model to best_weights_augment.h5
# Epoch 33/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.7498e-04 - val_loss: 6.3812e-04
#
# Epoch 00033: val_loss did not improve from 0.00061
# Epoch 34/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 1.6947e-04 - val_loss: 6.5743e-04
#
# Epoch 00034: val_loss did not improve from 0.00061
# Epoch 35/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.6794e-04 - val_loss: 6.2819e-04
#
# Epoch 00035: val_loss did not improve from 0.00061
# Epoch 36/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 1.6750e-04 - val_loss: 6.2045e-04
#
# Epoch 00036: val_loss did not improve from 0.00061
# Epoch 37/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.6329e-04 - val_loss: 6.2840e-04
#
# Epoch 00037: val_loss did not improve from 0.00061
# Epoch 38/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 1.6046e-04 - val_loss: 6.3501e-04
#
# Epoch 00038: val_loss did not improve from 0.00061
# Epoch 39/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.6002e-04 - val_loss: 6.2841e-04
#
# Epoch 00039: val_loss did not improve from 0.00061
# Epoch 40/150
# 3424/3424 [==============================] - 2s 476us/step - loss: 1.5266e-04 - val_loss: 6.2772e-04
#
# Epoch 00040: val_loss did not improve from 0.00061
# Epoch 41/150
# 3424/3424 [==============================] - 2s 476us/step - loss: 1.5383e-04 - val_loss: 6.1496e-04
#
# Epoch 00041: val_loss did not improve from 0.00061
# Epoch 42/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 1.5212e-04 - val_loss: 6.3128e-04
#
# Epoch 00042: val_loss did not improve from 0.00061
# Epoch 43/150
# 3424/3424 [==============================] - 2s 467us/step - loss: 1.4963e-04 - val_loss: 6.4525e-04
#
# Epoch 00043: val_loss did not improve from 0.00061
# Epoch 44/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 1.4721e-04 - val_loss: 6.1617e-04
#
# Epoch 00044: val_loss did not improve from 0.00061
# Epoch 45/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 1.4532e-04 - val_loss: 6.2892e-04
#
# Epoch 00045: val_loss did not improve from 0.00061
# Epoch 46/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 1.4684e-04 - val_loss: 6.4407e-04
#
# Epoch 00046: val_loss did not improve from 0.00061
# Epoch 47/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 1.4333e-04 - val_loss: 6.1857e-04
#
# Epoch 00047: val_loss did not improve from 0.00061
# Epoch 48/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 1.3883e-04 - val_loss: 6.3127e-04
#
# Epoch 00048: val_loss did not improve from 0.00061
# Epoch 49/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 1.3999e-04 - val_loss: 6.0373e-04
#
# Epoch 00049: val_loss improved from 0.00061 to 0.00060, saving model to best_weights_augment.h5
# Epoch 50/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 1.3527e-04 - val_loss: 6.4975e-04
#
# Epoch 00050: val_loss did not improve from 0.00060
# Epoch 51/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 1.3680e-04 - val_loss: 6.1539e-04
#
# Epoch 00051: val_loss did not improve from 0.00060
# Epoch 52/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 1.3476e-04 - val_loss: 6.1823e-04
#
# Epoch 00052: val_loss did not improve from 0.00060
# Epoch 53/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.2752e-04 - val_loss: 6.1163e-04
#
# Epoch 00053: val_loss did not improve from 0.00060
# Epoch 54/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 1.2739e-04 - val_loss: 6.3971e-04
#
# Epoch 00054: val_loss did not improve from 0.00060
# Epoch 55/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.2375e-04 - val_loss: 6.5637e-04
#
# Epoch 00055: val_loss did not improve from 0.00060
# Epoch 56/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.2417e-04 - val_loss: 6.3053e-04
#
# Epoch 00056: val_loss did not improve from 0.00060
# Epoch 57/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 1.2495e-04 - val_loss: 6.3581e-04
#
# Epoch 00057: val_loss did not improve from 0.00060
# Epoch 58/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 1.2682e-04 - val_loss: 6.2561e-04
#
# Epoch 00058: val_loss did not improve from 0.00060
# Epoch 59/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 1.2510e-04 - val_loss: 6.1587e-04
#
# Epoch 00059: val_loss did not improve from 0.00060
# Epoch 60/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.1943e-04 - val_loss: 6.2030e-04
#
# Epoch 00060: val_loss did not improve from 0.00060
# Epoch 61/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 1.1998e-04 - val_loss: 6.1256e-04
#
# Epoch 00061: val_loss did not improve from 0.00060
# Epoch 62/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.1738e-04 - val_loss: 6.1671e-04
#
# Epoch 00062: val_loss did not improve from 0.00060
# Epoch 63/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 1.1319e-04 - val_loss: 6.0798e-04
#
# Epoch 00063: val_loss did not improve from 0.00060
# Epoch 64/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.1388e-04 - val_loss: 6.0909e-04
#
# Epoch 00064: val_loss did not improve from 0.00060
# Epoch 65/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 1.1286e-04 - val_loss: 6.4872e-04
#
# Epoch 00065: val_loss did not improve from 0.00060
# Epoch 66/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 1.1225e-04 - val_loss: 6.1235e-04
#
# Epoch 00066: val_loss did not improve from 0.00060
# Epoch 67/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.0825e-04 - val_loss: 6.1310e-04
#
# Epoch 00067: val_loss did not improve from 0.00060
# Epoch 68/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 1.0775e-04 - val_loss: 6.1889e-04
#
# Epoch 00068: val_loss did not improve from 0.00060
# Epoch 69/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 1.0644e-04 - val_loss: 6.1254e-04
#
# Epoch 00069: val_loss did not improve from 0.00060
# Epoch 70/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.1072e-04 - val_loss: 6.5212e-04
#
# Epoch 00070: val_loss did not improve from 0.00060
# Epoch 71/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 1.0808e-04 - val_loss: 6.1058e-04
#
# Epoch 00071: val_loss did not improve from 0.00060
# Epoch 72/150
# 3424/3424 [==============================] - 2s 467us/step - loss: 1.0516e-04 - val_loss: 6.3091e-04
#
# Epoch 00072: val_loss did not improve from 0.00060
# Epoch 73/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 1.0493e-04 - val_loss: 6.0183e-04
#
# Epoch 00073: val_loss improved from 0.00060 to 0.00060, saving model to best_weights_augment.h5
# Epoch 74/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.0288e-04 - val_loss: 6.2937e-04
#
# Epoch 00074: val_loss did not improve from 0.00060
# Epoch 75/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.0315e-04 - val_loss: 6.2002e-04
#
# Epoch 00075: val_loss did not improve from 0.00060
# Epoch 76/150
# 3424/3424 [==============================] - 2s 467us/step - loss: 1.0365e-04 - val_loss: 5.8661e-04
#
# Epoch 00076: val_loss improved from 0.00060 to 0.00059, saving model to best_weights_augment.h5
# Epoch 77/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.0137e-04 - val_loss: 6.0000e-04
#
# Epoch 00077: val_loss did not improve from 0.00059
# Epoch 78/150
# 3424/3424 [==============================] - 2s 469us/step - loss: 1.0105e-04 - val_loss: 5.9104e-04
#
# Epoch 00078: val_loss did not improve from 0.00059
# Epoch 79/150
# 3424/3424 [==============================] - 2s 472us/step - loss: 1.0054e-04 - val_loss: 5.8966e-04
#
# Epoch 00079: val_loss did not improve from 0.00059
# Epoch 80/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.0020e-04 - val_loss: 6.1463e-04
#
# Epoch 00080: val_loss did not improve from 0.00059
# Epoch 81/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 1.0128e-04 - val_loss: 6.0958e-04
#
# Epoch 00081: val_loss did not improve from 0.00059
# Epoch 82/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 9.8844e-05 - val_loss: 6.2649e-04
#
# Epoch 00082: val_loss did not improve from 0.00059
# Epoch 83/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 9.5123e-05 - val_loss: 6.3381e-04
#
# Epoch 00083: val_loss did not improve from 0.00059
# Epoch 84/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 9.5805e-05 - val_loss: 6.1042e-04
#
# Epoch 00084: val_loss did not improve from 0.00059
# Epoch 85/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 9.5313e-05 - val_loss: 5.8381e-04
#
# Epoch 00085: val_loss improved from 0.00059 to 0.00058, saving model to best_weights_augment.h5
# Epoch 86/150
# 3424/3424 [==============================] - 2s 467us/step - loss: 9.4289e-05 - val_loss: 6.2311e-04
#
# Epoch 00086: val_loss did not improve from 0.00058
# Epoch 87/150
# 3424/3424 [==============================] - 2s 467us/step - loss: 9.3897e-05 - val_loss: 6.1192e-04
#
# Epoch 00087: val_loss did not improve from 0.00058
# Epoch 88/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 9.2768e-05 - val_loss: 6.3360e-04
#
# Epoch 00088: val_loss did not improve from 0.00058
# Epoch 89/150
# 3424/3424 [==============================] - 2s 467us/step - loss: 9.3050e-05 - val_loss: 6.2135e-04
#
# Epoch 00089: val_loss did not improve from 0.00058
# Epoch 90/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 9.1441e-05 - val_loss: 6.1806e-04
#
# Epoch 00090: val_loss did not improve from 0.00058
# Epoch 91/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 9.1091e-05 - val_loss: 6.3492e-04
#
# Epoch 00091: val_loss did not improve from 0.00058
# Epoch 92/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 9.0442e-05 - val_loss: 6.2052e-04
#
# Epoch 00092: val_loss did not improve from 0.00058
# Epoch 93/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 9.1154e-05 - val_loss: 6.1041e-04
#
# Epoch 00093: val_loss did not improve from 0.00058
# Epoch 94/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 9.1759e-05 - val_loss: 6.0362e-04
#
# Epoch 00094: val_loss did not improve from 0.00058
# Epoch 95/150
# 3424/3424 [==============================] - 2s 467us/step - loss: 9.1007e-05 - val_loss: 6.0027e-04
#
# Epoch 00095: val_loss did not improve from 0.00058
# Epoch 96/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 9.0894e-05 - val_loss: 5.9862e-04
#
# Epoch 00096: val_loss did not improve from 0.00058
# Epoch 97/150
# 3424/3424 [==============================] - 2s 470us/step - loss: 8.9579e-05 - val_loss: 6.2633e-04
#
# Epoch 00097: val_loss did not improve from 0.00058
# Epoch 98/150
# 3424/3424 [==============================] - 2s 467us/step - loss: 8.8819e-05 - val_loss: 6.1582e-04
#
# Epoch 00098: val_loss did not improve from 0.00058
# Epoch 99/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 8.7470e-05 - val_loss: 6.4774e-04
#
# Epoch 00099: val_loss did not improve from 0.00058
# Epoch 100/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 8.6436e-05 - val_loss: 6.1336e-04
#
# Epoch 00100: val_loss did not improve from 0.00058
# Epoch 101/150
# 3424/3424 [==============================] - 2s 469us/step - loss: 8.5838e-05 - val_loss: 6.2194e-04
#
# Epoch 00101: val_loss did not improve from 0.00058
# Epoch 102/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 8.5770e-05 - val_loss: 6.4414e-04
#
# Epoch 00102: val_loss did not improve from 0.00058
# Epoch 103/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 8.5613e-05 - val_loss: 6.3463e-04
#
# Epoch 00103: val_loss did not improve from 0.00058
# Epoch 104/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 8.1872e-05 - val_loss: 6.0110e-04
#
# Epoch 00104: val_loss did not improve from 0.00058
# Epoch 105/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 8.4181e-05 - val_loss: 6.0810e-04
#
# Epoch 00105: val_loss did not improve from 0.00058
# Epoch 106/150
# 3424/3424 [==============================] - 2s 470us/step - loss: 8.5648e-05 - val_loss: 6.1444e-04
#
# Epoch 00106: val_loss did not improve from 0.00058
# Epoch 107/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 8.5186e-05 - val_loss: 6.2966e-04
#
# Epoch 00107: val_loss did not improve from 0.00058
# Epoch 108/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 8.7527e-05 - val_loss: 6.0640e-04
#
# Epoch 00108: val_loss did not improve from 0.00058
# Epoch 109/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 8.5855e-05 - val_loss: 6.1946e-04
#
# Epoch 00109: val_loss did not improve from 0.00058
# Epoch 110/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 8.5209e-05 - val_loss: 6.1351e-04
#
# Epoch 00110: val_loss did not improve from 0.00058
# Epoch 111/150
# 3424/3424 [==============================] - 2s 469us/step - loss: 8.1172e-05 - val_loss: 5.9275e-04
#
# Epoch 00111: val_loss did not improve from 0.00058
# Epoch 112/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 8.3929e-05 - val_loss: 6.1536e-04
#
# Epoch 00112: val_loss did not improve from 0.00058
# Epoch 113/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 8.3417e-05 - val_loss: 6.2113e-04
#
# Epoch 00113: val_loss did not improve from 0.00058
# Epoch 114/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 8.2168e-05 - val_loss: 6.0918e-04
#
# Epoch 00114: val_loss did not improve from 0.00058
# Epoch 115/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 8.1041e-05 - val_loss: 6.0911e-04
#
# Epoch 00115: val_loss did not improve from 0.00058
# Epoch 116/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 8.0946e-05 - val_loss: 6.1615e-04
#
# Epoch 00116: val_loss did not improve from 0.00058
# Epoch 117/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 8.3141e-05 - val_loss: 6.3159e-04
#
# Epoch 00117: val_loss did not improve from 0.00058
# Epoch 118/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 8.2951e-05 - val_loss: 6.3667e-04
#
# Epoch 00118: val_loss did not improve from 0.00058
# Epoch 119/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 7.9834e-05 - val_loss: 6.1781e-04
#
# Epoch 00119: val_loss did not improve from 0.00058
# Epoch 120/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 8.1418e-05 - val_loss: 6.3075e-04
#
# Epoch 00120: val_loss did not improve from 0.00058
# Epoch 121/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 7.9857e-05 - val_loss: 5.9998e-04
#
# Epoch 00121: val_loss did not improve from 0.00058
# Epoch 122/150
# 3424/3424 [==============================] - 2s 470us/step - loss: 8.0328e-05 - val_loss: 6.1296e-04
#
# Epoch 00122: val_loss did not improve from 0.00058
# Epoch 123/150
# 3424/3424 [==============================] - 2s 473us/step - loss: 8.0833e-05 - val_loss: 6.1017e-04
#
# Epoch 00123: val_loss did not improve from 0.00058
# Epoch 124/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 8.0372e-05 - val_loss: 6.1670e-04
#
# Epoch 00124: val_loss did not improve from 0.00058
# Epoch 125/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 7.7574e-05 - val_loss: 6.1243e-04
#
# Epoch 00125: val_loss did not improve from 0.00058
# Epoch 126/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 7.7995e-05 - val_loss: 6.3867e-04
#
# Epoch 00126: val_loss did not improve from 0.00058
# Epoch 127/150
# 3424/3424 [==============================] - 2s 448us/step - loss: 7.7502e-05 - val_loss: 6.1736e-04
#
# Epoch 00127: val_loss did not improve from 0.00058
# Epoch 128/150
# 3424/3424 [==============================] - 2s 448us/step - loss: 7.6997e-05 - val_loss: 6.1511e-04
#
# Epoch 00128: val_loss did not improve from 0.00058
# Epoch 129/150
# 3424/3424 [==============================] - 2s 448us/step - loss: 7.7665e-05 - val_loss: 6.2324e-04
#
# Epoch 00129: val_loss did not improve from 0.00058
# Epoch 130/150
# 3424/3424 [==============================] - 2s 447us/step - loss: 7.8203e-05 - val_loss: 6.0430e-04
#
# Epoch 00130: val_loss did not improve from 0.00058
# Epoch 131/150
# 3424/3424 [==============================] - 2s 450us/step - loss: 7.8453e-05 - val_loss: 6.0552e-04
#
# Epoch 00131: val_loss did not improve from 0.00058
# Epoch 132/150
# 3424/3424 [==============================] - 2s 450us/step - loss: 7.7255e-05 - val_loss: 6.1247e-04
#
# Epoch 00132: val_loss did not improve from 0.00058
# Epoch 133/150
# 3424/3424 [==============================] - 2s 445us/step - loss: 7.7933e-05 - val_loss: 6.2310e-04
#
# Epoch 00133: val_loss did not improve from 0.00058
# Epoch 134/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 7.8033e-05 - val_loss: 6.3753e-04
#
# Epoch 00134: val_loss did not improve from 0.00058
# Epoch 135/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 7.7018e-05 - val_loss: 6.0774e-04
#
# Epoch 00135: val_loss did not improve from 0.00058
# Epoch 136/150
# 3424/3424 [==============================] - 2s 454us/step - loss: 7.5868e-05 - val_loss: 6.1644e-04
#
# Epoch 00136: val_loss did not improve from 0.00058
# Epoch 137/150
# 3424/3424 [==============================] - 2s 451us/step - loss: 7.6463e-05 - val_loss: 6.0904e-04
#
# Epoch 00137: val_loss did not improve from 0.00058
# Epoch 138/150
# 3424/3424 [==============================] - 2s 447us/step - loss: 7.6284e-05 - val_loss: 6.2196e-04
#
# Epoch 00138: val_loss did not improve from 0.00058
# Epoch 139/150
# 3424/3424 [==============================] - 2s 449us/step - loss: 7.6421e-05 - val_loss: 5.9831e-04
#
# Epoch 00139: val_loss did not improve from 0.00058
# Epoch 140/150
# 3424/3424 [==============================] - 2s 451us/step - loss: 7.7187e-05 - val_loss: 6.1305e-04
#
# Epoch 00140: val_loss did not improve from 0.00058
# Epoch 141/150
# 3424/3424 [==============================] - 2s 446us/step - loss: 7.6546e-05 - val_loss: 6.1559e-04
#
# Epoch 00141: val_loss did not improve from 0.00058
# Epoch 142/150
# 3424/3424 [==============================] - 2s 449us/step - loss: 7.6911e-05 - val_loss: 5.9655e-04
#
# Epoch 00142: val_loss did not improve from 0.00058
# Epoch 143/150
# 3424/3424 [==============================] - 2s 450us/step - loss: 7.3892e-05 - val_loss: 6.2088e-04
#
# Epoch 00143: val_loss did not improve from 0.00058
# Epoch 144/150
# 3424/3424 [==============================] - 2s 448us/step - loss: 7.5953e-05 - val_loss: 6.2166e-04
#
# Epoch 00144: val_loss did not improve from 0.00058
# Epoch 145/150
# 3424/3424 [==============================] - 2s 450us/step - loss: 7.6260e-05 - val_loss: 6.1043e-04
#
# Epoch 00145: val_loss did not improve from 0.00058
# Epoch 146/150
# 3424/3424 [==============================] - 2s 447us/step - loss: 7.4449e-05 - val_loss: 6.1563e-04
#
# Epoch 00146: val_loss did not improve from 0.00058
# Epoch 147/150
# 3424/3424 [==============================] - 2s 452us/step - loss: 7.4538e-05 - val_loss: 6.4819e-04
#
# Epoch 00147: val_loss did not improve from 0.00058
# Epoch 148/150
# 3424/3424 [==============================] - 2s 450us/step - loss: 7.8400e-05 - val_loss: 6.0531e-04
#
# Epoch 00148: val_loss did not improve from 0.00058
# Epoch 149/150
# 3424/3424 [==============================] - 2s 448us/step - loss: 7.5297e-05 - val_loss: 6.0330e-04
#
# Epoch 00149: val_loss did not improve from 0.00058
# Epoch 150/150
# 3424/3424 [==============================] - 2s 450us/step - loss: 7.3862e-05 - val_loss: 6.0459e-04
#
# Epoch 00150: val_loss did not improve from 0.00058

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
